# %%
import matplotlib.pyplot as plt
import pandas as pd
import importlib

import pyfraglib.scores as scores

importlib.reload(scores)
# Out:
# <module 'pyfraglib.scores' from '/home/daniel/.local/lib/python3.10/site-packages/pyfraglib/scores.py'>

# %%
data: pd.DataFrame = pd.read_csv("../scores_out/wps_DED005_BL_0.01.csv",
                                 dtype={"chrom": "str", "pos": "int64", "wps": "int64", "info": "str"})

# %%
scores.make_wps_plot(data, "DED005_BL_0.01", ".")
# Out:
# INFO:pyfraglib:asaving WPS plot for DED005_BL_0.01 to `./DED005_BL_0.01_wps.png'
